# %% [markdown]
# ## Week 2 - grpa 3
#
#
# Given a custom implementation of list named MyList. On MyList objects you can perform read operations similar to the in-build lists in Python, example use A[i] to read element at index i  in MyList object A. The only possible operation that you can use to edit data  in MyList objects is by calling the swap method. For instance, A.swap(indexA, B , indexB) will swap values at A[indexA] and B[indexB] and A.swap(index1, A , index2) will swap values at A[index1] and A[index2], where indexA , indexB , index1 , index2 are all integers.
#
# Complete the Python function mergeInPlace(A, B) that accepts two MyLists  A and B containing integers that are sorted in ascending order and merges them inplace(without using any other list) such that after merging,  A and B are still sorted in ascending order with the smallest element of both MyLists as  the first element of  A .
#
# **Note:- Your function should not return any list and should only merge the given sorted lists inplace.**
#
# Some Examples:
#
# Sample Input:
# 2 4 6 9 13 15
# 1 3 5 10
#
# Sample Output:
#
# [1, 2, 3, 4, 5 ,6]
# [9 ,10 ,13 ,15]
#
# Sample Input:
# 4 6
# 1 3 6 10
#
# Sample Output:
#
# 1 3
# 4 6 6 10

# %% [markdown]
# Initially i didnt understand the problem ..Chatgpt (windows copilot)explained it as follows:
#
# Sure, I will try to explain the problem in simple words. 😊
#
# The problem is about how to merge two lists of numbers that are already sorted from smallest to largest. For example, if you have two lists like this:
#
# A = [2, 4, 6, 9, 13, 15]
# B = [1, 3, 5, 10]
#
# You want to merge them so that they become like this:
#
# A = [1, 2, 3, 4, 5, 6]
# B = [9, 10, 13, 15]
#
# The catch is that you cannot create a new list or copy any values from one list to another. You can only swap values between the two lists using a special method called swap. For example, if you want to swap the first value of A with the first value of B, you can write:
#
# A.swap(0, B, 0)
#
# This will change the lists to:
#
# A = [1, 4, 6, 9, 13, 15]
# B = [2, 3, 5, 10]
#
# The challenge is to write a function that can merge any two sorted lists in this way, using only the swap method and without creating any new lists or copying any values.
#
# I hope this explanation helps you understand the problem better. 😊
#
# Solution is given here:

# %%
def mergeInPlace(A, B):
    # Initialize the indices for A and B
    i = 0
    j = 0
    # Loop until one of the lists is exhausted
    while i < len(A) and j < len(B):
        # If the value at A[i] is greater than the value at B[j]
        if A[i] > B[j]:
            # Swap the values
            A.swap(i, B, j)
            # Increment the index for A
            i += 1
            # Find the correct position for the swapped value in B
            # Initialize a variable to store the current index in B
            k = j
            # Loop until the end of B or until the value at B[k] is less than or equal to the value at B[k+1]
            while k < len(B) - 1 and B[k] > B[k+1]:
                # Swap the values
                B.swap(k, B, k+1)
                # Increment the index for B
                k += 1
        # Otherwise, if the value at A[i] is less than or equal to the value at B[j]
        else:
            # Increment the index for A
            i += 1
    # Return nothing as the lists are merged in place
    return
